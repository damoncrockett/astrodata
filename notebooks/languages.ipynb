# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./languages.csv")

# %%
df
# Out:
#                               language  \
# 0                              english
# 1                              spanish
# 2                               arabic
# 3                            afrikaans
# 4                               basque
# 5                           belarusian
# 6                              bengali
# 7                     bosnian/croatian
# 8                    bulgarian/russian
# 9   catalan/galician/italian/portugese
# 10                             chinese
# 11                            corsican
# 12                 czech/polish/slovak
# 13                              danish
# 14                      dutch/romanian
# 15                            estonian
# 16                              french
# 17                              german
# 18                               greek
# 19             haitian creole/sudanese
# 20                              hebrew
# 21                           hungarian
# 22                           icelandic
# ...
